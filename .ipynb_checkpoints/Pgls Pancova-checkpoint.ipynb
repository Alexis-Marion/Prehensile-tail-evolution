# %% [markdown]
# # Phylogenetic generalised regression and Phylogenetic ANCOVA

# %% [markdown]
# ## Cleaning and loading data

# %% [markdown]
# ### Loading packages

# %%
library("phytools")
library("nlme")
library("multcomp")
library("evomap")
library("geiger")
library("phylolm")
library("dplyr")
# Out:
# Le chargement a nécessité le package : ape
#
# Le chargement a nécessité le package : maps
#
# Le chargement a nécessité le package : mvtnorm
#
# Le chargement a nécessité le package : survival
#
# Le chargement a nécessité le package : TH.data
#
# Le chargement a nécessité le package : MASS
#
#
# Attachement du package : ‘TH.data’
#
#
# L'objet suivant est masqué depuis ‘package:MASS’:
#
#     geyser
#
#
#
# Attachement du package : ‘dplyr’
#
#
# L'objet suivant est masqué depuis ‘package:MASS’:
#
#     select
#
#
# L'objet suivant est masqué depuis ‘package:nlme’:
#
#     collapse
#
#
# L'objet suivant est masqué depuis ‘package:ape’:
#
#     where
#
#
# Les objets suivants sont masqués depuis ‘package:stats’:
#
#     filter, lag
#
#
# Les objets suivants sont masqués depuis ‘package:base’:
#
#     intersect, setdiff, setequal, union

# %% [markdown]
# ### Loading data

# %%
read.table("data/Complete_Table.tsv", header = TRUE)
# Out:
#    Nomenclature Genus_species            Prehensility Locomotion Climbing
# 1  ABEsevi      Abeomelomys_sevia        P            ARB        CLI
# 2  AETchry      Aethomys_chrysophilus    N            SCA        CLI
# 3  ANIimit      Anisomys_imitator        N            SCA        CLI
# 4  APOdata      Apomys_datae             N            TER        NCL
# 5  BANindi      Bandicota_indica         N            TER        NCL
# 6  BUNchry      Bunomys_chrysocomus      N            TER        NCL
# 7  CHIforb      Chiruromys_forbesi       P            ARB        CLI
# 8  CHIglir      Chiropodomys_gliroides   N            ARB        CLI
# 9  CHIlami      Chiruromys_lamia         P            ARB        CLI
# 10 CHImajo      Chiropodomys_major       N            ARB        CLI
# 11 CHIpulc      Chiruromys_pulcher       P            ARB        CLI
# 12 CHIvate      Chiruromys_vates         P            ARB        CLI
# 13 COCshaw      Coccymys_shawmayeri      P            SCA        CLI
# 14 CONpeni      Conilurus_penicillatus   N            SCA        CLI
# 15 CRAhean      Crateromys_heaneyi       N            ARB        CLI
# 16 GOLelli      Golunda_ellioti          N            TER        NCL
# 17 HAEmina      Haeromys_minahassae      N            ARB        CLI
# 18 HAPlong      Hapalomys_longicaudatus  N            ARB        CLI
# 19 HYDchry      Hydromys_chrisogaster    N            AQU        NCL
# 20 HYOgol2      Hyomys_goliath_2         N            TER        NCL
# 21 HYOgoli      Hyomys_goliath           P            TER        NCL
# 22 LEGforr      Leggadina_forresti       N            TER        NCL
# 23 LEMstri      Lemniscomys_striatus     N            TER        NCL
# 24 LENcana      Lenothrix_cana           N            ARB        CLI
# 25 LEPcond      Leporillus_conditor      N            TER        NCL
# 26 LEPspce      Leptomys_sp              N            TER        NCL
# 27 LORnouh      Lorentzimys_nouhuysi     N            ARB        CLI
# 28 MACmajo      Macruromys_major         N            TER        NCL
# 29 MALherc      Mallomys_hercules        P            SCA        CLI
# 30 MALista      Mallomys_istapantap      P            TER        NCL
# ⋮  ⋮            ⋮                        ⋮            ⋮          ⋮
# 36 MICminu      Micromys_minutus         P            SCA        CLI
# 37 MICnama      Micaelamys_namaquensis   N            SCA        CLI
# 38 MICspce      Microhydromys_sp         N            TER        NCL
# 39 MILmelt      Millardia_meltada        N            TER        NCL
# 40 NIVcrem      Niviventer_cremoriventer N            ARB        CLI
# 41 NOTalex      Notomys_alexis           N            SAL        NCL
# 42 PARaspe      Parahydromys_asper       N            TER        NCL
# 43 PARspce      Paramelomys_sp           N            TER        NCL
# 44 PHLcumi      Phloeomys_cumingi        N            ARB        CLI
# 45 PHLpall      Phloeomys_pallidus       N            ARB        CLI
# 46 PITmela      Pithecheir_melanurus     P            ARB        CLI
# 47 POGlori      Pogonomys_loriae         P            ARB        CLI
# 48 POGmacr      Pogonomys_macrourus      P            ARB        CLI
# 49 POGmaye      Pogonomelomys_mayeri     P            ARB        CLI
# 50 POGsylv      Pogonomys_sylvestris     P            ARB        CLI
# 51 PROfell      Protochromys_fellowsi    P            NA_        NA_
# 52 PSEaust      Pseudomys_australis      N            TER        NCL
# 53 RATmacl      Rattus_macleari          N            ARB        CLI
# 54 RATnati      Rattus_nativitatis       N            TER        NCL
# 55 RHYisar      Rhynchomys_isarogensis   N            TER        NCL
# 56 SOLsapi      Solomys_sapientis        P            ARB        CLI
# 57 TAEarcu      Taeromys_arcuatus        N            TER        NCL
# 58 TAEdomi      Taeromys_dominator       N            SCA        CLI
# 59 THApoen      Thamnomys_poensis        N            ARB        CLI
# 60 THAspce      Thallomys_spce           N            ARB        CLI
# 61 UROcaud      Uromys_caudimaculatus    N            SCA        CLI
# 62 UROimpe      Uromys_imperator         N            TER        NCL
# 63 UROrex_      Uromys_rex               P            ARB        CLI
# 64 VANoler      Vandeleuria_oleracea     N            ARB        CLI
# 65 ZYZargu      Zyzomys_argurus          N            TER        NCL
#    Vert_numb TailLength Proxy_size_raw Proxy_size_GM RImean   RIproxmean
# 1  43.0      159.61505  1.7711915      1.5817870     38.82047  76.90756
# 2  35.0      146.09375  2.3262007      1.4970520     30.71918  72.71975
# 3  36.0      251.20415  4.1309520      2.7092460     36.71494 100.73983
# 4  32.0      124.37299  2.1419709      1.6858259     36.82276  72.82170
# 5  33.0      283.77216  5.1106935      3.6729077     39.13203  81.99695
# 6  27.0      126.51945  2.3764939      1.7618503     34.59575  79.98836
# 7  41.5      202.70115  2.3793972      2.0611526     38.18693  77.38870
# 8  35.0       77.77957  1.2356295      0.9324887     31.85341  80.04872
# 9  43.0      172.94069  1.7804432      1.6616054     34.50145  68.09902
# 10 32.0       94.58154  1.5071522      1.1844139     29.71021  76.06377
# 11 40.0      213.37628  2.5102447      2.2593804     36.69566  71.00484
# 12 42.0      166.83684  1.7153488      1.4199599     38.62829  78.52995
# 13 45.0      140.49188  1.3115160      1.2345681     37.93700  75.03618
# 14 33.0      177.80523  2.7072953      1.8466555     26.00658  76.11371
# 15 22.0      249.29694  4.8636557      6.8274494     46.82230  78.39934
# 54 70.41361     77.05347
# 55 48.54342     56.88149
# 56 67.63402     73.68030
# 57 36.62943     37.85482
# 58 40.87408     38.85328
# 59 34.69800     32.47047
# 60 37.21513     38.01690
# 61 42.61691     47.10658
# 62 59.17720     68.31830
# 63 64.99967     73.30022
# 64 36.39066     46.86535
# 65 29.34939     27.14806

# %%
table_1<-read.table("data/table_complete_LDA.tsv", header = TRUE)
phy<-read.tree(file = "data/Tree_65_sp_murids.tree")

# %%
tablePANCOVA <- na.omit(table)

# %%
phy_omit <- drop.tip(phy,c("Uromys_imperator","Hyomys_goliath_2"))

# %% [markdown]
# ### Creating useful functions

# %% [markdown]
# #### Plotting grade regression (after Smaers' evomap package)

# %%
pGLS.plotGrade<-function (Yvar, Xvar, data, tree, model, group, ...) 
{
    dataTemp <- pruneSample(na.omit(data), tree, group)$data
    treeTemp <- pruneSample(dataTemp, tree, group)$tree
    Y <- dataTemp[, which(colnames(dataTemp) == paste(Yvar))]
    X <- dataTemp[, which(colnames(dataTemp) == paste(Xvar))]
    dataGLS <- as.data.frame(cbind(Y, X))
    rownames(dataGLS) <- rownames(dataTemp)
     switch(model, BM = {
        pGLSTemp <- phylolm(Y ~ X, data=dataGLS, phy=treeTemp,model = "BM")
        }, lambda = {
        pGLSTemp <- phylolm(Y ~ X, data=dataGLS, phy=treeTemp,model = "lambda")
        })
    a <- summary(pGLSTemp)$coefficients[1, 1]
    b <- summary(pGLSTemp)$coefficients[2, 1]
    lines(c(min(X), max(X)), c((a + b * min(X)), (a + b * max(X))), 
        ...)
    points(X, Y, ...)
}

# %% [markdown]
# #### Extracting taxa name following their ecological group

# %%
extract.group<-function(tree, data_frame, group1){
  vec_gr1<-c()
  vec_gr2<-c()
  for (i in 1:nrow(data_frame)){
    if(data_frame[i,20]==group1){
      vec_gr1<-c(vec_gr1, which(tree$tip.label==data_frame[i,2]))
    }
    else{
      vec_gr2<-c(vec_gr2, which(tree$tip.label==data_frame[i,2]))
    }
  }
  return(list(vec_gr1, vec_gr2))
}

# %% [markdown]
# #### Automatised function performing phylogenetic GLS & ANCOVA

# %%
pancova<-function(temp_data, phy, df, iterator, spp, df_temp){
  
  temp_data[,1]<-log(temp_data[,1])
  
  rownames(temp_data)<-df[,2]
  
  colnames(temp_data)<-c("Dependent","Independent")

  Non_p<-unlist(extract.group(phy, df, "N")[1])
  P<-unlist(extract.group(phy, df, "N")[2])
  Non_p<-unlist(extract.group(phy, df, "N")[1])
  P<-unlist(extract.group(phy, df, "N")[2])

  plot(temp_data$Dependent~temp_data$Independent,col="white",pch=19,xlab="", ylab="",asp=1,cex.lab=2)
  pGLS.plotGrade("Dependent","Independent",temp_data,phy,model="BM",group=Non_p,col="#D2B48C",lwd=5,cex=1,pch=19)
  pGLS.plotGrade("Dependent","Independent",temp_data,phy,model="BM",group=P,col="#40826D",lwd=5,cex=1,pch=19)
  tipCol<-rep("#40826D",length(phy$tip.label))
  tipCol[Non_p]<-"#D2B48C"
  plot(phy,tip.col=tipCol,cex=0.6)
  df$Prehensility_LDA<-as.factor(df$Prehensility_LDA)
  corBM<-corBrownian(phy=phy,form=~spp)
    

    prehensility.ancova<-gls(log(Y)~log(X)*Group -1, correlation=corBM, data = df_temp)
    post.hoc<-glht(prehensility.ancova,linfct=mcp(Group="Tukey"))
    print(summary(post.hoc))
    df<-prehensility.ancova$dims$N-prehensility.ancova$dims$p
    alpha<-0.05
    ciBeta_Non_prehensile<-coef(prehensility.ancova)["log(X)"]+
    qt(c(alpha/2,1-alpha/2),df)*
    sqrt(prehensility.ancova$varBeta["log(X)","log(X)"])
    print(ciBeta_Non_prehensile)
    ciBeta_Prehensile<-coef(prehensility.ancova)["log(X)"]+
    coef(prehensility.ancova)["log(X):GroupP"]+
    qt(c(alpha/2,1-alpha/2),df)*
    sqrt(prehensility.ancova$varBeta[ "log(X)","log(X)"]+
    prehensility.ancova$varBeta["log(X):GroupP","log(X):GroupP"]+2*prehensility.ancova$varBeta["log(X)","log(X):GroupP"])
    CIs<-data.frame(parameter= paste("beta(",levels(table$Prehensility),")",sep=""),lower=c(ciBeta_Non_prehensile[1],ciBeta_Prehensile[1]), estimate=coef(prehensility.ancova)["log(X)"]+c(0, coef(prehensility.ancova)[c("log(X):GroupP")]), upper=c(ciBeta_Non_prehensile[2],ciBeta_Prehensile[2]))
    rownames(CIs)<-NULL
    print(intervals(prehensility.ancova))
}

# %% [markdown]
# ## Performing the Phylogenetic linear regression and Covariance analyses

# %%
for (i in c(10,13,14,15,18,19)){
  df_temp<-tablePANCOVA[,c(2,20,i,9)]
  colnames(df_temp)<-c("Genus_species", "Group", "Y", "X")
  df_temp$Group<-as.factor(df_temp$Group)
  spp<-tablePANCOVA[,2]
  pancova(tablePANCOVA[,c(i,10)], phy_omit, tablePANCOVA, i, spp, df_temp)
}
# Out:
# Warning message in mcp2matrix(model, linfct = linfct):
# “covariate interactions found -- default contrast might be inappropriate”
# 	 Simultaneous Tests for General Linear Hypotheses
#
# Multiple Comparisons of Means: Tukey Contrasts
#
#
# Fit: gls(model = log(Y) ~ log(X) * Group - 1, data = df_temp, correlation = corBM)
#
# Linear Hypotheses:
#            Estimate Std. Error z value Pr(>|z|)
# P - N == 0   6.9024     0.1753   39.37   <2e-16 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
# (Adjusted p values reported -- single-step method)
#
# [1] 0.1368490 0.3033225
# Error in pancova(tablePANCOVA[, c(i, 10)], phy_omit, tablePANCOVA, i, : objet 'ciBeta_Cathemeral' introuvable
# Traceback:
#
# 1. pancova(tablePANCOVA[, c(i, 10)], phy_omit, tablePANCOVA, i,
#  .     spp, df_temp)
# 2. data.frame(parameter = paste("beta(", levels(table$Prehensility),
#  .     ")", sep = ""), lower = c(ciBeta_Non_prehensile[1], ciBeta_Prehensile[1]),
#  .     estimate = coef(prehensility.ancova)["log(X)"] + c(0, coef(prehensility.ancova)[c("log(X):GroupP")]),
#  .     upper = c(ciBeta_Cathemeral[2], ciBeta_Prehensile[2]))   # at line 38 of file <text>
# plot without title
# plot without title
